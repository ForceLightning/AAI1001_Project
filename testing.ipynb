# %%
import os
import sys

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.autonotebook import tqdm

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

from fastai.data.core import DataLoaders

from scripts.utils import *
import scripts.pp_cnf_matrix as ppcm
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_49524\3602494544.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
sns.set("notebook", "whitegrid")

# %%
train_set = ECGDataset("./data/heartbeats_evensplit_train/", item_transform=hb_transform, target_transform=label_encode)
test_set = ECGDataset("./data/heartbeats_evensplit_test/", target_transform=label_encode)

# %%
train_set = ECGDataset("./data/heartbeats_train/", item_transform=hb_transform, target_transform=label_encode)
test_set = ECGDataset("./data/heartbeats_test/", target_transform=label_encode)

train_loader = DataLoader(train_set, batch_size=4096, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=4096, shuffle=False, pin_memory=True)

# %%
train_loader = DataLoader(train_set, batch_size=2048, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=2048, shuffle=False, pin_memory=True)

# %%
dls = DataLoaders(test_loader)

# %% [markdown]
# # Inference on Test Set

# %%
import importlib
importlib.reload(sys.modules['scripts.utils'])
from scripts.utils import *

# %%
model = TCN(360, 5, [32]*9, 2, 0.125, use_skip_connections=True)
# learner = Learner(dls, model, loss_func=nn.CrossEntropyLoss(), metrics=accuracy)
# learner.load("./prototyping/tcn_fold_1/best")

# %%
model_outputs, classification_reports = k_fold_inference(model, test_loader, model_dir='./prototyping8/tcn_fold_', weights_fn="best")
# Out:
# ./prototyping8/tcn_fold_1/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping8/tcn_fold_2/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping8/tcn_fold_3/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping8/tcn_fold_4/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping8/tcn_fold_5/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping8/tcn_fold_6/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping8/tcn_fold_7/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping8/tcn_fold_8/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping8/tcn_fold_9/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping8/tcn_fold_10/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
k_fold_roc_curve(model_outputs, "TCN prototype 6")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# Handy Dandy Bookmark

# %%
k_fold_roc_curve(model_outputs, "TCN prototype 6", average="weighted")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# Prototype 7

# %%
k_fold_roc_curve(model_outputs, "TCN Prototype 8")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
k_fold_roc_curve(model_outputs, "TCN Prototype 8", average="weighted")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
model_outputs[0]["preds"], model_outputs[0]["y"]
# Out:
# (tensor([2, 0, 2,  ..., 2, 2, 2]), tensor([0, 0, 0,  ..., 0, 2, 0]))

# %% [markdown]
# # Confusion Matrices

# %%
for report in classification_reports:
    display(pd.DataFrame(report))
# Out:
#                       N            S            V      F            Q  \
# precision      0.930349     0.189189     0.423947    0.0     0.912281
# recall         0.900762     0.010791     0.908063    0.0     0.704062
# f1-score       0.915316     0.020418     0.578030    0.0     0.794760
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.850031      0.491153      0.854114
# recall     0.850031      0.504736      0.850031
# f1-score   0.850031      0.461705      0.842226
# support    0.850031  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.922976     0.183036     0.481969    0.0     0.976000
# recall         0.921268     0.021069     0.892992    0.0     0.589942
# f1-score       0.922121     0.037788     0.626046    0.0     0.735383
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.862287      0.512796      0.854261
# recall     0.862287      0.485054      0.862287
# f1-score   0.862287      0.464267      0.849800
# support    0.862287  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.925245     0.283784     0.366053    0.0     0.974564
# recall         0.870874     0.010791     0.923637    0.0     0.648453
# f1-score       0.897237     0.020792     0.524312    0.0     0.778746
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.823926      0.509929      0.851311
# recall     0.823926      0.490751      0.823926
# f1-score   0.823926      0.444217      0.822556
# support    0.823926  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.915710     0.225641     0.426056    0.0     0.990446
# recall         0.897642     0.022610     0.948003    0.0     0.300774
# f1-score       0.906586     0.041102     0.587896    0.0     0.461424
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.835602      0.511570      0.846160
# recall     0.835602      0.433806      0.835602
# f1-score   0.835602      0.399402      0.823840
# support    0.835602  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.916601     0.359375     0.380991    0.0     0.993464
# recall         0.880923     0.011819     0.932429    0.0     0.367505
# f1-score       0.898408     0.022886     0.540950    0.0     0.536534
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.822532      0.530086      0.848486
# recall     0.822532      0.438535      0.822532
# f1-score   0.822532      0.399755      0.815747
# support    0.822532  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.925345     0.139344     0.441817    0.0     0.986070
# recall         0.910272     0.008736     0.891736    0.0     0.650387
# f1-score       0.917747     0.016441     0.590879    0.0     0.783800
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.854774      0.498515      0.852198
# recall     0.854774      0.492226      0.854774
# f1-score   0.854774      0.461773      0.844646
# support    0.854774  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.933077     0.120205     0.384885    0.0     0.900796
# recall         0.873628     0.024152     0.937704    0.0     0.711315
# f1-score       0.902375     0.040223     0.545760    0.0     0.794920
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.830081      0.467793      0.850734
# recall     0.830081      0.509360      0.830081
# f1-score   0.830081      0.456656      0.829715
# support    0.830081  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.927879     0.247863     0.408103    0.0     0.952667
# recall         0.896114     0.014902     0.895755    0.0     0.691006
# f1-score       0.911720     0.028114     0.560736    0.0     0.801009
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.844889      0.507302      0.854473
# recall     0.844889      0.499555      0.844889
# f1-score   0.844889      0.460316      0.838458
# support    0.844889  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.928557     0.081365     0.375140    0.0     0.960159
# recall         0.869475     0.015930     0.926400    0.0     0.699226
# f1-score       0.898045     0.026644     0.534028    0.0     0.809177
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision   0.82503      0.469044      0.847082
# recall      0.82503      0.502206      0.825030
# f1-score    0.82503      0.453579      0.825282
# support     0.82503  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.932365     0.072000     0.409076    0.0     0.957588
# recall         0.889573     0.013875     0.926149    0.0     0.698743
# f1-score       0.910466     0.023266     0.567493    0.0     0.807940
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision   0.84183      0.474206      0.852306
# recall      0.84183      0.505668      0.841830
# f1-score    0.84183      0.461833      0.837979
# support     0.84183  55238.000000  55238.000000

# %%
for fold in model_outputs:
    cnf_matrix = confusion_matrix(
        fold["y"],
        fold["preds"]
    )
    cnf_matrix = pd.DataFrame(cnf_matrix, columns=["N", "S", "V", "F", "Q"])
    ppcm.pretty_plot_confusion_matrix(cnf_matrix)

# %% [markdown]
# # Training Graphs

# %%
fig, ax = plt.subplots(2, 1, figsize=(8.27, 11.69), dpi=100, sharex=True)
for i in tqdm(range(10)):
    plot_df = pd.read_csv(f'models/prototyping8/tcn_fold_{i+1}/log.csv')
    ax[0].plot(plot_df["train_loss"], label=f"Fold {i+1}", alpha=0.5)
    ax[1].plot(plot_df["valid_loss"], label=f"Fold {i+1}", alpha=0.5)
ax[0].set_title("Training Loss")
ax[1].set_title("Validation Loss")
ax[0].set_ylabel("Loss")
ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
ax[0].legend()
ax[1].legend()
fig.suptitle("Training and Validation Loss vs Epoch")
plt.show()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots(2, 1, figsize=(8.27, 11.69), dpi=100, sharex=True)
for i in tqdm(range(10)):
    plot_df = pd.read_csv(f'models/prototyping7/tcn_fold_{i+1}/log.csv')
    ax[0].plot(plot_df["train_loss"], label=f"Fold {i+1}", alpha=0.5)
    ax[1].plot(plot_df["valid_loss"], label=f"Fold {i+1}", alpha=0.5)
ax[0].set_title("Training Loss")
ax[1].set_title("Validation Loss")
ax[0].set_ylabel("Loss")
ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
ax[0].legend()
ax[1].legend()
fig.suptitle("Training and Validation Loss vs Epoch")
plt.show()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
