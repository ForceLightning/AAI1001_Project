# %%
import os
import sys

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.autonotebook import tqdm

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

from fastai.data.core import DataLoaders

from scripts.utils import *
import scripts.pp_cnf_matrix as ppcm
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_38496\3602494544.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
sns.set("notebook", "whitegrid")

# %%
train_set = ECGDataset("./data/heartbeats_evensplit_train/", item_transform=hb_transform, target_transform=label_encode)
test_set = ECGDataset("./data/heartbeats_evensplit_test/", target_transform=label_encode)

# %%
train_set = ECGDataset("./data/heartbeats_train/", item_transform=hb_transform, target_transform=label_encode)
test_set = ECGDataset("./data/heartbeats_test/", target_transform=label_encode)

train_loader = DataLoader(train_set, batch_size=4096, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=4096, shuffle=False, pin_memory=True)

# %%
train_loader = DataLoader(train_set, batch_size=2048, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=2048, shuffle=False, pin_memory=True)

# %%
dls = DataLoaders(test_loader)

# %% [markdown]
# # Inference on Test Set

# %%
import importlib
importlib.reload(sys.modules['scripts.utils'])
from scripts.utils import *

# %%
model = TCN(360, 5, [32]*9, 2, 0.125, use_skip_connections=True)
# learner = Learner(dls, model, loss_func=nn.CrossEntropyLoss(), metrics=accuracy)
# learner.load("./prototyping/tcn_fold_1/best")

# %%
model_outputs, classification_reports = k_fold_inference(model, test_loader, model_dir='./prototyping7/tcn_fold_', weights_fn="best")
# Out:
# ./prototyping7/tcn_fold_1/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping7/tcn_fold_2/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping7/tcn_fold_3/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping7/tcn_fold_4/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping7/tcn_fold_5/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping7/tcn_fold_6/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping7/tcn_fold_7/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping7/tcn_fold_8/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping7/tcn_fold_9/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping7/tcn_fold_10/best
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
k_fold_roc_curve(model_outputs, "TCN prototype 6")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# Handy Dandy Bookmark

# %%
k_fold_roc_curve(model_outputs, "TCN prototype 6", average="weighted")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# Prototype 7

# %%
k_fold_roc_curve(model_outputs, "TCN Prototype 7")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
k_fold_roc_curve(model_outputs, "TCN Prototype 7", average="weighted")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
model_outputs[0]["preds"], model_outputs[0]["y"]
# Out:
# (tensor([2, 0, 2,  ..., 2, 2, 2]), tensor([0, 0, 0,  ..., 0, 2, 0]))

# %% [markdown]
# # Confusion Matrices

# %%
for report in classification_reports:
    display(pd.DataFrame(report))
# Out:
#                       N            S            V      F            Q  \
# precision      0.917325     0.019486     0.334810    0.0     0.455245
# recall         0.838964     0.022610     0.607636    0.0     0.715667
# f1-score       0.876396     0.020932     0.431733    0.0     0.556496
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.777237      0.345373      0.813643
# recall     0.777237      0.436976      0.777237
# f1-score   0.777237      0.377111      0.790035
# support    0.777237  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.917884     0.018610     0.241579    0.0     0.316816
# recall         0.667685     0.025180     0.870133    0.0     0.683269
# f1-score       0.773044     0.021402     0.378166    0.0     0.432904
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.650929      0.298978      0.802181
# recall     0.650929      0.449253      0.650929
# f1-score   0.650929      0.321103      0.694609
# support    0.650929  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.893099     0.021287     0.310443    0.0     0.143773
# recall         0.779102     0.022097     0.793770    0.0     0.173598
# f1-score       0.832215     0.021684     0.446328    0.0     0.157284
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.719975      0.273720      0.779907
# recall     0.719975      0.353713      0.719975
# f1-score   0.719975      0.291502      0.738996
# support    0.719975  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.930825     0.034251     0.427882    0.0     0.583837
# recall         0.826053     0.057554     0.868124    0.0     0.747582
# f1-score       0.875315     0.042945     0.573229    0.0     0.655640
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.787574      0.395359      0.837043
# recall     0.787574      0.499863      0.787574
# f1-score   0.787574      0.429426      0.803810
# support    0.787574  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.931198     0.024548     0.368128    0.0     0.245693
# recall         0.710591     0.066290     0.746797    0.0     0.765474
# f1-score       0.806073     0.035828     0.493158    0.0     0.371989
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.682664      0.313913      0.820049
# recall     0.682664      0.457830      0.682664
# f1-score   0.682664      0.341410      0.728913
# support    0.682664  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.900520     0.029087     0.396792    0.0     0.468109
# recall         0.860546     0.040596     0.720924    0.0     0.198743
# f1-score       0.880079     0.033891     0.511860    0.0     0.279022
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision   0.78484      0.358902      0.804791
# recall      0.78484      0.364162      0.784840
# f1-score    0.78484      0.340971      0.788977
# support     0.78484  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.907786     0.039586     0.595460    0.0     0.165861
# recall         0.842428     0.045221     0.705099    0.0     0.414894
# f1-score       0.873887     0.042216     0.645658    0.0     0.236984
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.776712      0.341739      0.814277
# recall     0.776712      0.401528      0.776712
# f1-score   0.776712      0.359749      0.792129
# support    0.776712  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.900157     0.033912     0.581344    0.0     0.096928
# recall         0.874726     0.063207     0.727958    0.0     0.068665
# f1-score       0.887259     0.044141     0.646442    0.0     0.080385
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.793204      0.322468      0.804060
# recall     0.793204      0.346911      0.793204
# f1-score   0.793204      0.331646      0.797641
# support    0.793204  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.902884     0.018620     0.481538    0.0     0.458909
# recall         0.909412     0.017472     0.632253    0.0     0.305126
# f1-score       0.906136     0.018028     0.546699    0.0     0.366541
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.822731      0.372390      0.812174
# recall     0.822731      0.372852      0.822731
# f1-score   0.822731      0.367481      0.816128
# support    0.822731  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.887727     0.024201     0.241888    0.0     0.048420
# recall         0.716271     0.038541     0.741522    0.0     0.057060
# f1-score       0.792836     0.029732     0.364782    0.0     0.052386
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.659564      0.240447      0.766980
# recall     0.659564      0.310679      0.659564
# f1-score   0.659564      0.247947      0.696344
# support    0.659564  55238.000000  55238.000000

# %%
for fold in model_outputs:
    cnf_matrix = confusion_matrix(
        fold["y"],
        fold["preds"]
    )
    cnf_matrix = pd.DataFrame(cnf_matrix, columns=["N", "S", "V", "F", "Q"])
    ppcm.pretty_plot_confusion_matrix(cnf_matrix)

# %% [markdown]
# # Training Graphs

# %%
fig, ax = plt.subplots(2, 1, figsize=(8.27, 11.69), dpi=100, sharex=True)
for i in tqdm(range(10)):
    plot_df = pd.read_csv(f'models/prototyping6/tcn_fold_{i+1}/log.csv')
    ax[0].plot(plot_df["train_loss"], label=f"Fold {i+1}", alpha=0.5)
    ax[1].plot(plot_df["valid_loss"], label=f"Fold {i+1}", alpha=0.5)
ax[0].set_title("Training Loss")
ax[1].set_title("Validation Loss")
ax[0].set_ylabel("Loss")
ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
ax[0].legend()
ax[1].legend()
fig.suptitle("Training and Validation Loss vs Epoch")
plt.show()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots(2, 1, figsize=(8.27, 11.69), dpi=100, sharex=True)
for i in tqdm(range(10)):
    plot_df = pd.read_csv(f'models/prototyping7/tcn_fold_{i+1}/log.csv')
    ax[0].plot(plot_df["train_loss"], label=f"Fold {i+1}", alpha=0.5)
    ax[1].plot(plot_df["valid_loss"], label=f"Fold {i+1}", alpha=0.5)
ax[0].set_title("Training Loss")
ax[1].set_title("Validation Loss")
ax[0].set_ylabel("Loss")
ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
ax[0].legend()
ax[1].legend()
fig.suptitle("Training and Validation Loss vs Epoch")
plt.show()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
