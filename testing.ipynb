# %%
import os
import sys

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.autonotebook import tqdm

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

from fastai.data.core import DataLoaders

from scripts.utils import *
import scripts.pp_cnf_matrix as ppcm
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_9548\3602494544.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
sns.set("notebook", "whitegrid")

# %%
train_set = ECGDataset("./data/heartbeats_train/", item_transform=hb_transform, target_transform=label_encode)
test_set = ECGDataset("./data/heartbeats_test/", target_transform=label_encode)

train_loader = DataLoader(train_set, batch_size=4096, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=4096, shuffle=False, pin_memory=True)

# %%
train_set = ECGDataset("./data/heartbeats_evensplit_train/", item_transform=hb_transform, target_transform=label_encode)
test_set = ECGDataset("./data/heartbeats_evensplit_test/", target_transform=label_encode)

train_loader = DataLoader(train_set, batch_size=2048, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=2048, shuffle=False, pin_memory=True)

# %%
dls = DataLoaders(test_loader)

# %% [markdown]
# # Inference on Test Set

# %%
import importlib
importlib.reload(sys.modules['scripts.utils'])
from scripts.utils import *

# %%
model = TCN(360, 5, [32]*9, 2, 0.125, use_skip_connections=True)
# learner = Learner(dls, model, loss_func=nn.CrossEntropyLoss(), metrics=accuracy)
# learner.load("./prototyping/tcn_fold_1/best")

# %%
model_outputs, classification_reports = k_fold_inference(model, test_loader, model_dir='./prototyping5/tcn_fold_', weights_fn="epoch_99")
# Out:
# ./prototyping5/tcn_fold_1/epoch_99
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping5/tcn_fold_2/epoch_99
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping5/tcn_fold_3/epoch_99
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping5/tcn_fold_4/epoch_99
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping5/tcn_fold_5/epoch_99
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping5/tcn_fold_6/epoch_99
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping5/tcn_fold_7/epoch_99
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping5/tcn_fold_8/epoch_99
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping5/tcn_fold_9/epoch_99
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ./prototyping5/tcn_fold_10/epoch_99
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\chris\.virtualenvs\AAI1001-GKVhCZq-\lib\site-packages\fastai\learner.py:59: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
model_outputs[0]["preds"]
# Out:
# tensor([2, 0, 2,  ..., 2, 2, 2])

# %%
np.bincount(model_outputs[0]["y"].numpy().tolist())
# Out:
# array([10035,   232,  1649,   378,     1], dtype=int64)

# %%
k_fold_roc_curve(model_outputs, "TCN")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
k_fold_roc_curve(model_outputs, "TCN")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# Handy Dandy Bookmark

# %%
k_fold_roc_curve(model_outputs, "TCN", average="weighted")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
k_fold_roc_curve(model_outputs, "TCN Prototype 5")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
k_fold_roc_curve(model_outputs, "TCN Prototype 5", average="weighted")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
model_outputs[0]["preds"], model_outputs[0]["y"]
# Out:
# (tensor([2, 0, 2,  ..., 2, 2, 2]), tensor([0, 0, 0,  ..., 0, 2, 0]))

# %% [markdown]
# # Confusion Matrices

# %%
for report in classification_reports:
    display(pd.DataFrame(report))
# Out:
#                       N            S            V      F            Q  \
# precision      0.901323     0.078125     0.578709    0.0     0.798354
# recall         0.946744     0.017986     0.832957    0.0     0.093810
# f1-score       0.923476     0.029240     0.682937    0.0     0.167893
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.860712      0.471302      0.832669
# recall     0.860712      0.378299      0.860712
# f1-score   0.860712      0.360709      0.833493
# support    0.860712  55238.000000  55238.000000
#                       N            S            V      F       Q  accuracy  \
# precision      0.878262     0.010363     0.814291    0.0     0.0  0.865781
# recall         0.980613     0.003083     0.563929    0.0     0.0  0.865781
# f1-score       0.926619     0.004752     0.666370    0.0     0.0  0.865781
# support    46474.000000  1946.000000  3981.000000  769.0  2068.0  0.865781
#
#               macro avg  weighted avg
# precision      0.340583      0.797969
# recall         0.309525      0.865781
# f1-score       0.319548      0.827796
# support    55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.897490     0.007463     0.452059    0.0     0.426104
# recall         0.921591     0.001028     0.763878    0.0     0.107350
# f1-score       0.909380     0.001807     0.567987    0.0     0.171495
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision   0.83448      0.356623      0.803890
# recall      0.83448      0.358769      0.834480
# f1-score    0.83448      0.330134      0.812518
# support     0.83448  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.922587     0.052933     0.786391    0.0     0.719836
# recall         0.963958     0.019013     0.792514    0.0     0.680851
# f1-score       0.942819     0.027977     0.789441    0.0     0.699801
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.894294      0.496349      0.861700
# recall     0.894294      0.491267      0.894294
# f1-score   0.894294      0.492008      0.877312
# support    0.894294  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.892569     0.021898     0.791427    0.0     0.471572
# recall         0.985755     0.001542     0.691032    0.0     0.068182
# f1-score       0.936851     0.002880     0.737830    0.0     0.119138
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.881766      0.435493      0.826419
# recall     0.881766      0.349302      0.881766
# f1-score   0.881766      0.359340      0.845948
# support    0.881766  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.912803     0.061728     0.824176    0.0     0.906283
# recall         0.986143     0.005139     0.810098    0.0     0.411509
# f1-score       0.948057     0.009488     0.817076    0.0     0.566013
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.903653      0.540998      0.863481
# recall     0.903653      0.442578      0.903653
# f1-score   0.903653      0.468127      0.878050
# support    0.903653  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.898766     0.035235     0.702715    0.0     0.753351
# recall         0.966820     0.010791     0.754082    0.0     0.135880
# f1-score       0.931552     0.016522     0.727493    0.0     0.230234
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.873239      0.478013      0.836259
# recall     0.873239      0.373515      0.873239
# f1-score   0.873239      0.381160      0.845385
# support    0.873239  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.910754     0.049505     0.511534    0.0     0.794902
# recall         0.931704     0.010277     0.824416    0.0     0.331721
# f1-score       0.921110     0.017021     0.631336    0.0     0.468100
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.856077      0.453339      0.834625
# recall     0.856077      0.419624      0.856077
# f1-score   0.856077      0.407513      0.838592
# support    0.856077  55238.000000  55238.000000
#                       N            S            V      F            Q  \
# precision      0.873813     0.021303     0.918642    0.0     0.005952
# recall         0.982377     0.008736     0.428284    0.0     0.000967
# f1-score       0.924920     0.012391     0.584204    0.0     0.001664
# support    46474.000000  1946.000000  3981.000000  769.0  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.857725      0.363942      0.802355
# recall     0.857725      0.284073      0.857725
# f1-score   0.857725      0.304636      0.820776
# support    0.857725  55238.000000  55238.000000
#                       N            S            V           F            Q  \
# precision      0.920004     0.022843     0.509578    0.090909     0.763504
# recall         0.917847     0.009250     0.855313    0.003901     0.505803
# f1-score       0.918924     0.013168     0.638657    0.007481     0.608493
# support    46474.000000  1946.000000  3981.000000  769.000000  2068.000000
#
#            accuracy     macro avg  weighted avg
# precision  0.853181      0.461368      0.841417
# recall     0.853181      0.458423      0.853181
# f1-score   0.853181      0.437345      0.842505
# support    0.853181  55238.000000  55238.000000

# %%
for fold in model_outputs:
    cnf_matrix = confusion_matrix(
        fold["y"].cpu().numpy(),
        fold["preds"].cpu().numpy()
    )
    cnf_matrix = pd.DataFrame(cnf_matrix, columns=["N", "S", "V", "F", "Q"])
    ppcm.pretty_plot_confusion_matrix(cnf_matrix)

# %% [markdown]
# # Training Graphs

# %%
fig, ax = plt.subplots(2, 1, figsize=(8.27, 11.69), dpi=100, sharex=True)
for i in tqdm(range(10)):
    plot_df = pd.read_csv(f'models/prototyping5/tcn_fold_{i+1}/log.csv')
    ax[0].plot(plot_df["train_loss"], label=f"Fold {i+1}", alpha=0.5)
    ax[1].plot(plot_df["valid_loss"], label=f"Fold {i+1}", alpha=0.5)
ax[0].set_title("Training Loss")
ax[1].set_title("Validation Loss")
ax[0].set_ylabel("Loss")
ax[1].set_ylabel("Loss")
ax[1].set_xlabel("Epoch")
ax[0].legend()
ax[1].legend()
fig.suptitle("Training and Validation Loss vs Epoch")
plt.show()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
